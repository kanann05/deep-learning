# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
import numpy as np
from tensorflow import keras

# %%
from tensorflow.keras import Input
from tensorflow.keras import layers

# %%
num_classes = 10
input_shape = (28, 28, 1)
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 7s 1us/step

# %%
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

# %%
model = keras.Sequential([
    keras.Input(shape = input_shape),
    keras.layers.Conv2D(32, kernel_size = (3, 3), activation = 'relu'),
    keras.layers.MaxPooling2D(pool_size = (2, 2)),

    keras.layers.Conv2D(64, kernel_size = (3, 3), activation = 'relu'),
    keras.layers.MaxPooling2D(pool_size = (2, 2)),

    keras.layers.Flatten(),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(10, activation = 'softmax')
])

# %%
batch_size = 128
epochs = 15

model.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics = ['accuracy'])
history = model.fit(x_train, y_train, batch_size = batch_size, epochs= epochs, validation_split = 0.1)

score = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.5416 - loss: 1.4703 - val_accuracy: 0.8705 - val_loss: 0.4916
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.8200 - loss: 0.5815 - val_accuracy: 0.9133 - val_loss: 0.3275
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.8643 - loss: 0.4464 - val_accuracy: 0.9347 - val_loss: 0.2456
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.8930 - loss: 0.3614 - val_accuracy: 0.9520 - val_loss: 0.1913
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9067 - loss: 0.3131 - val_accuracy: 0.9583 - val_loss: 0.1635
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9169 - loss: 0.2769 - val_accuracy: 0.9642 - val_loss: 0.1420
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9231 - loss: 0.2520 - val_accuracy: 0.9673 - val_loss: 0.1287
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9306 - loss: 0.2312 - val_accuracy: 0.9715 - val_loss: 0.1159
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9343 - loss: 0.2171 - val_accuracy: 0.9725 - val_loss: 0.1097
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9389 - loss: 0.2037 - val_accuracy: 0.9757 - val_loss: 0.1016
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9419 - loss: 0.1933 - val_accuracy: 0.9762 - val_loss: 0.0994
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9441 - loss: 0.1852 - val_accuracy: 0.9765 - val_loss: 0.0976
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9470 - loss: 0.1761 - val_accuracy: 0.9767 - val_loss: 0.0937
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9485 - loss: 0.1686 - val_accuracy: 0.9772 - val_loss: 0.0884
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9504 - loss: 0.1626 - val_accuracy: 0.9778 - val_loss: 0.0887
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9729 - loss: 0.0918
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 8
#       5 history = model.fit(x_train, y_train, batch_size = batch_size, epochs= epochs, validation_split = 0.1)
#       7 score = model.evaluate(x_test, y_test)
# ----> 8 print("Accuracy : " + score[1])
#       9 print("Loss : " + score[0])
#
# TypeError: can only concatenate str (not "float") to str

# %%
print("Accuracy : " + str(score[1]))
print("Loss : " + str(score[0]))
# Out:
# Accuracy : 0.9728999733924866
# Loss : 0.09176260232925415
